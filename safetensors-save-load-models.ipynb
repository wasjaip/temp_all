# %% [markdown]
# <a href="https://www.kaggle.com/code/wasjaip/safetensors-save-load-models?scriptVersionId=154890432" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install -U sentence-transformers

# %% [markdown]
# для локалного запуска чтобы safetensors

# %%
# !pip install diffusers
# !pip install git+https://github.com/huggingface/diffusers

# %%
# !pip install safetensors

# %% [markdown]
# глянуть версии

# %%
# !pip show safetensors
# Out:
# Name: safetensors
# Version: 0.4.1
# Summary:
# Home-page:
# Author:
# Author-email: Nicolas Patry <patry.nicolas@protonmail.com>
# License:
# Location: /opt/conda/lib/python3.10/site-packages
# Requires:
# Required-by: accelerate, timm, transformers

# %%
# !pip show diffusers
# Out:
# WARNING: Package(s) not found: diffusers

# %%
# !pip show sentence-transformers
# Out:
# Name: sentence-transformers
# Version: 2.2.2
# Summary: Multilingual text embeddings
# Home-page: https://github.com/UKPLab/sentence-transformers
# Author: Nils Reimers
# Author-email: info@nils-reimers.de
# License: Apache License 2.0
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: huggingface-hub, nltk, numpy, scikit-learn, scipy, sentencepiece, torch, torchvision, tqdm, transformers
# Required-by:

# %%
from sentence_transformers import SentenceTransformer

# Загрузка модели путь менять как надо .. тут с хагинфейс
model = SentenceTransformer('sentence-transformers/LaBSE')

# %%
# Сохранение модели в директории, доступной на Kaggle
model.save('/kaggle/working/model')

# %%
# Проверка файлов в директории сохранения
import os
print(os.listdir('/kaggle/working/model'))

# %%
from sentence_transformers import SentenceTransformer

# Загрузка модели из директории
model = SentenceTransformer('/kaggle/working/model')

# %%
model

# %% [markdown]
# архив

# %%
# !tar -czf model.tar.gz -C /kaggle/working/model .

# %%
import os
os.path.exists('/kaggle/working/model.tar.gz')
